# %%
import os
import numpy as np
import pandas as pd
from PIL import Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#!unzip "drive/MyDrive/earner_ambiguities.zip" -d "drive/MyDrive/Learner_ambiguities"
# Out:
# unzip:  cannot find or open drive/MyDrive/earner_ambiguities.zip, drive/MyDrive/earner_ambiguities.zip.zip or drive/MyDrive/earner_ambiguities.zip.ZIP.

# %%
folder_path = "drive/MyDrive/Learner_ambiguities"
output_path = "white_pixel.xlsx"

# %%
image_files = [f for f in os.listdir(folder_path) if f.endswith(".png")]
data = []
for file in image_files:
    image_path = os.path.join(folder_path, file)
    image = Image.open(image_path).convert("L")
    image_array = np.array(image)
    white_pixels = np.argwhere(image_array >= 150)
    for pixel in white_pixels:
        row_cord = pixel[0]
        col_cord = pixel[1]
        data.append([file, row_cord, col_cord])

# %%
df = pd.DataFrame(data, columns=["File_Name", "Row_Coordinate", "Column_Coordinate"])

# %%
df.head()
# Out:
#                           File_Name  Row_Coordinate  Column_Coordinate
# 0  amb_Prediction_drishtiGS_101.png             239                380
# 1  amb_Prediction_drishtiGS_101.png             239                381
# 2  amb_Prediction_drishtiGS_101.png             239                382
# 3  amb_Prediction_drishtiGS_101.png             239                383
# 4  amb_Prediction_drishtiGS_101.png             239                384

# %%
df.shape
# Out:
# (5926, 3)

# %%
df.to_excel(output_path, index=False)
